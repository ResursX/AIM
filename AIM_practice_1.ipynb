# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Lab1\\data\\titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### 1. Разбиение таблицы по полу
#
# C удалением пустых строк

# %%
df_male = df[df['Sex'] == 'male'].dropna()
df_female = df[df['Sex'] == 'female'].dropna()

# %%
df_male
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 6              7         0       1               McCarthy, Mr. Timothy J
# 21            22         1       2                 Beesley, Mr. Lawrence
# 23            24         1       1          Sloper, Mr. William Thompson
# 27            28         0       1        Fortune, Mr. Charles Alexander
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# ..           ...       ...     ...                                   ...
# 806          807         0       1                Andrews, Mr. Thomas Jr
# 857          858         1       1                Daly, Mr. Peter Denis
# 867          868         0       1  Roebling, Mr. Washington Augustus II
# 872          873         0       1              Carlsson, Mr. Frans Olof
# 889          890         1       1                 Behr, Mr. Karl Howell
#
#       Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
df_female
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 10            11         1       3
# 11            12         1       1
# 52            53         1       1
# ..           ...       ...     ...
# 853          854         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### 2. Гистограмма распределения пассажиров по возрасту

# %%
df['Age'].plot(kind='hist', bins=50)
plt.xlabel('Возраст')
plt.ylabel('Кол-во пассажиров')
plt.grid(axis='y')
plt.show()

# %%
df['Age'].quantile([0.25,0.75]) # квартили
# Out:
# 0.25    20.125
# 0.75    38.000
# Name: Age, dtype: float64

# %% [markdown]
# ### 3. Вычислите мин и макс, среднее, моду, медиану возраста пассажира каждого пола

# %%
df.groupby('Sex').agg({'Age': ['min', 'max', 'mean', pd.Series.mode, 'median']}, axis='columns')
# Out:
#          Age
#          min   max       mean                mode median
# Sex
# female  0.75  63.0  27.915709                24.0   27.0
# male    0.42  80.0  30.726645  [19.0, 25.0, 28.0]   29.0

# %% [markdown]
# ### 4. Визуализировать возраст при помощи различных настроек метода plot

# %%
df_male['Age'].plot(kind='line', label='Male', color='blue')
df_female['Age'].plot(kind='line', label='Female', color='purple')

plt.title('Age lineplot')
plt.ylabel('Age')
plt.show()

# %%
df_male['Age'].plot(kind='hist', label='Male', color='blue', alpha=0.7, bins=15)
df_female['Age'].plot(kind='hist', label='Female', color='purple', alpha=0.7, bins=15)

plt.title('Age histogram')
plt.ylabel('Age')
plt.show()

# %%
df_male['Age'].plot(kind='box', label='Male', color='blue')
df_female['Age'].plot(kind='box', label='Female', color='purple')

plt.title('Age boxplot')
plt.ylabel('Age')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[82], line 4
#       1 plt.figure(figsize=(8, 6))
#       3 df_male['Age'].plot(kind='box', label='Male', color='blue')
# ----> 4 df_female['Age'].plot(kind='box', label='Female', color='purple')
#       6 plt.title('Age boxplot')
#       7 plt.ylabel('Age')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\plotting\_core.py:1031, in PlotAccessor.__call__(self, *args, **kwargs)
#    1028             label_name = label_kw or data.columns
#    1029             data.columns = label_name
# -> 1031 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ...

# %%
df_male['Age'].plot(kind='kde', label='Male', color='blue')
df_female['Age'].plot(kind='kde', label='Female', color='purple')

plt.title('Density graph')
plt.ylabel('Age')
plt.show()

# %%
plt.scatter(df_male.index, df_male['Age'], label='Male', color='blue', alpha=0.6)
plt.scatter(df_female.index, df_female['Age'], label='Female', color='purple', alpha=0.6)

plt.title('Точечная диаграмма')
plt.ylabel('Возраст')
plt.legend()
plt.show()
